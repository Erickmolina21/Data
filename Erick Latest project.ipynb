# %% [markdown]
# # NYPD Arrest Data Analysis
# ### Intro: by Tania
# On our second project , we decided to work on NYPD arrest data. This data is year to date. This is a breakdown of every arrest affected in NYC by the NYPD during the current year. It was created on June 5, 2018 and it got updated on November 1,2019. Also,  This is a breakdown of every arrest affected in NYC by the NYPD during the current year. This data is manually extracted every quarter and reviewed by the Office of Management Analysis and Planning. Each record represents an arrest affected in NYC by the NYPD and includes information about the type of crime, the location and time of enforcement. It is not an automated data. The data is entered under the city agency of Police Department (NYPD). This data has about 20.8k views. Moreover , it has 168k rows and 18 columns. We are going to analyze the data. We will use pandas to import the csv file. then we will start analyzing in the Jupyter notebook. With the help of this data, we can figure out what is the rate of the arrest in NYC. Also, very important issues will come up. analyzing the data correctly, can show us , what type of crimes happen highly, what level of crime, which borough has the most crime reports, which precinct has the most arrest records. We will break down the data to also find the rate of crimes comitted by gender and age of the suspects. the age and gender rate of crimes commited on the current year. out the  and many important crime report will come up.. link to our [dataset](https://data.cityofnewyork.us/Public-Safety/NYPD-Arrest-Data-Year-to-Date-/uip8-fykc) also another data set https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Current-Year-To-Date-/5uac-w243

# %% [markdown]
# ### COLUMN DESCRIPTION: by Jorge
# 1. ARREST_KEY - Randomly generated persistent ID for each arrest
# 2. ARREST_DATE - Exact date of arrest for the reported event
# 3. PD_CD - Three digit internal classification code (more granular than Key Code)
# 4. PD_DESC - Description of internal classification corresponding with PD code (more granular than Offense Description)
# 5. KY_CD - Three digit internal classification code (more general category than PD code)
# 6. OFNS_DESC - Description of internal classification corresponding with KY code (more general category than PD description)
# 7. LAW_CODE - Law code charges corresponding to the NYS Penal Law, VTL and other various local laws
# 8. LAW_CAT_CD -Level of offense: felony, misdemeanor, violation
# 9. ARREST_BORO - Borough of arrest. B(Bronx), S(Staten Island), K(Brooklyn), M(Manhattan), Q(Queens)
# 10. ARREST_PRECINCT - Precinct where the arrest occurred
# 11. JURISDICTION_CODE - Jurisdiction responsible for arrest. Jurisdiction codes 0(Patrol), 1(Transit) and 2(Housing) represent NYPD whilst codes 3 and more represent non NYPD jurisdictions
# 12. AGE_GROUP - Perpetrator’s age within a category
# 13. PERP_SEX - Perpetrator’s sex description
# 14. PERP_RACE - Perpetrator’s race description
# 15. X_COORD_CD - Midblock X-coordinate for New York State Plane Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)
# 16. Y_COORD_CD - Midblock Y-coordinate for New York State Plane Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)
# 17. Latitude - Latitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)
# 18. Longitude - Longitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)

# %% [markdown]
# COLUMN DESCRIPTION COMPLAINT DATA
#
# 1.    CMPLNT_NUM - Randomly generated persistent ID for each complaint
# 2.    ADDR_PCT_CD - The precinct in which the incident occurred
# Number
# 3.    BORO_NM - The name of the borough in which the incident occurred
# 4.    CMPLNT_FR_DT -Exact date of occurrence for the reported event (or starting date of occurrence, if CMPLNT_TO_DT exists)
# 5.    CMPLNT_FR_TM - Exact time of occurrence for the reported event (or starting time of occurrence, if CMPLNT_TO_TM exists)
# 6.    CMPLNT_TO_DT - Ending date of occurrence for the reported event, if exact time of occurrence is unknown
# 7.    CMPLNT_TO_TM - Ending time of occurrence for the reported event, if exact time of occurrence is unknown
# 8.    CRM_ATPT_CPTD_CD- Indicator of whether crime was successfully completed or attempted, but failed or was interrupted prematurely
# 9.    HADEVELOPT- Name of NYCHA housing development of occurrence, if applicable
# 10.  HOUSING_PSA- Development Level Code
# 11.  JURISDICTION_CODE- Jurisdiction responsible for incident. Either internal, like Police(0), Transit(1), and Housing(2); or external(3), like Correction, Port Authority, etc.
# 12.  JURIS_DESC- Description of the jurisdiction code
# 13.  KY_CD- Three digit offense classification code
# 14.  LAW_CAT_CD- Level of offense: felony, misdemeanor, violation
# 15.  LOC_OF_OCCUR_DESC- Specific location of occurrence in or around the premises; inside, opposite of, front of, rear of
# 16.  OFNS_DESC- Description of offense corresponding with key code
# 17.  PARKS_NM- Name of NYC park, playground or greenspace of occurrence, if applicable (state parks are not included)
# 18.  PATROL_BORO- The name of the patrol borough in which the incident occurred
# 19.  PD_CD- Three digit internal classification code (more granular than Key Code)
# 20.  PD_DESC- Description of internal classification corresponding with PD code (more granular than Offense Description)
# 21.  PREM_TYP_DESC- Specific description of premises; grocery store, residence, street, etc.
# 22.  RPT_DT- Date event was reported to police
# 23.  STATION_NAME- Transit station name
# 24.  SUSP_AGE_GROUP- Suspect’s Age Group
# 25.  SUSP_RACE- Suspect’s Race Description
# 26.  SUSP_SEX-Suspect’s Sex Description
# 27.  TRANSIT_DISTRICT- Transit district in which the offense occurred.
# 28.  VIC_AGE_GROUP- Victim’s Age Group
# 29.  VIC_RACE- Victim’s Race Description
# 30.  VIC_SEX- Victim’s Sex Description
# 31.  X_COORD_CD- X-coordinate for New York State Plane Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)
#
# 32.  Y_COORD_CD- Y-coordinate for New York State Plane Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)
# 33.  Latitude- Midblock Latitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)
# 34.  Longitude- Midblock Longitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)
# 35.  Lat_Lon

# %% [markdown]
# ### Erick, jorge, santosh

# %%
import pandas as pd

# %%
arrest = pd.read_csv("NYPD_Arrest_Data__Year_to_Date_.csv",parse_dates=['ARREST_DATE'])

# %%
arrest.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0   203078287  2019-09-30  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 1   203072424  2019-09-30  268.0              CRIMINAL MIS 2 & 3  121.0
# 2   203061215  2019-09-30  905.0     INTOXICATED DRIVING,ALCOHOL  347.0
# 3   203061218  2019-09-30  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 4   203063729  2019-09-30  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
#
#                         OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                         ROBBERY  PL 1600500          F           M
# 1  CRIMINAL MISCHIEF & RELATED OF  PL 1450502          F           Q
# 2  INTOXICATED & IMPAIRED DRIVING  VTL11920U3          M           S
# 3                         ROBBERY  PL 1601502          F           S
# 4                         ROBBERY  PL 1601001          F           Q
#
#    ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# ...

# %%
arrest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167965 entries, 0 to 167964
# Data columns (total 18 columns):
# ARREST_KEY           167965 non-null int64
# ARREST_DATE          167965 non-null datetime64[ns]
# PD_CD                167930 non-null float64
# PD_DESC              167848 non-null object
# KY_CD                167848 non-null float64
# OFNS_DESC            167848 non-null object
# LAW_CODE             167965 non-null object
# LAW_CAT_CD           167003 non-null object
# ARREST_BORO          167965 non-null object
# ARREST_PRECINCT      167965 non-null int64
# JURISDICTION_CODE    167965 non-null int64
# AGE_GROUP            167965 non-null object
# PERP_SEX             167965 non-null object
# PERP_RACE            167965 non-null object
# X_COORD_CD           167965 non-null int64
# Y_COORD_CD           167965 non-null int64
# Latitude             167965 non-null float64
# Longitude            167965 non-null float64
# ...

# %%
(arrest.groupby(['AGE_GROUP'])
.agg({'ARREST_KEY':'count'}).sort_values(by= 'ARREST_KEY',ascending=False))
# Out:
#            ARREST_KEY
# AGE_GROUP
# 25-44           89456
# 18-24           34355
# 45-64           33812
# <18              7998
# 65+              2344

# %% [markdown]
# #### Arrest key represents the number of crimes by age group

# %%
arrest['PERP_SEX'].value_counts()
# Out:
# M    137135
# F     30830
# Name: PERP_SEX, dtype: int64

# %%
(arrest.groupby(['PERP_SEX'])
.agg({'ARREST_KEY':'count'}).sort_values(by= 'ARREST_KEY',ascending=False))
# Out:
#           ARREST_KEY
# PERP_SEX
# M             137135
# F              30830

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
(arrest.groupby(['PERP_SEX','AGE_GROUP'])
.agg({'ARREST_KEY':'count'}))
# Out:
#                     ARREST_KEY
# PERP_SEX AGE_GROUP
# F        18-24            6785
#          25-44           16482
#          45-64            5643
#          65+               366
#          <18              1554
# M        18-24           27570
#          25-44           72974
#          45-64           28169
#          65+              1978
#          <18              6444

# %% [markdown]
# #### Bar graph of crimes by age group and gender

# %%
arrest.groupby(['AGE_GROUP','PERP_SEX']).size().plot.bar()

# %% [markdown]
# ###  Bar graph of number of crimes by age group and gender
# ####  Our data shows that males and females 25 to 44 with 72,974 and 16,482 crimes respectively are the top perpetrators so far this year.

# %%
(arrest.groupby(['AGE_GROUP'])
.agg({'OFNS_DESC':lambda x:x.value_counts().index[0],
      'ARREST_KEY':'count'})).plot()

# %% [markdown]
# #### Highest arrests number by age aroup
# >#### 25-44: 89456
# >
# #### Lowest arrests number by age group
# >#### 65+: 2344

# %% [markdown]
# #### Scatter plot representing the locations where the alleged crimes were committed

# %%
arrest.groupby(['AGE_GROUP','PERP_RACE']).agg({'ARREST_KEY':'count'})
# Out:
#                                           ARREST_KEY
# AGE_GROUP PERP_RACE
# 18-24     AMERICAN INDIAN/ALASKAN NATIVE         114
#           ASIAN / PACIFIC ISLANDER              1898
#           BLACK                                17410
#           BLACK HISPANIC                        3627
#           UNKNOWN                                232
#           WHITE                                 2535
#           WHITE HISPANIC                        8539
# 25-44     AMERICAN INDIAN/ALASKAN NATIVE         245
#           ASIAN / PACIFIC ISLANDER              5003
#           BLACK                                40941
#           BLACK HISPANIC                        7936
#           UNKNOWN                                670
#           WHITE                                11255
#           WHITE HISPANIC                       23406
# 45-64     AMERICAN INDIAN/ALASKAN NATIVE          86
#           ASIAN / PACIFIC ISLANDER              2080
# ...

# %%
arr_piv = arrest.pivot_table(index='AGE_GROUP',
                columns='PERP_SEX',
                values='ARREST_KEY',
                aggfunc='count')

# %%
arrest['ones'] = 1

# %%
totals = arrest.groupby(['AGE_GROUP']).agg({'ones':'sum'})

# %%
totals['ones']
# Out:
# AGE_GROUP
# 18-24    34355
# 25-44    89456
# 45-64    33812
# 65+       2344
# <18       7998
# Name: ones, dtype: int64

# %%
arr_piv['F_proportion'] = arr_piv['F']/totals['ones']
arr_piv['M_proportion'] = arr_piv['M']/totals['ones']

# %%
arr_piv
# Out:
# PERP_SEX       F      M  F_proportion  M_proportion
# AGE_GROUP
# 18-24       6785  27570      0.197497      0.802503
# 25-44      16482  72974      0.184247      0.815753
# 45-64       5643  28169      0.166893      0.833107
# 65+          366   1978      0.156143      0.843857
# <18         1554   6444      0.194299      0.805701

# %%
w=(arrest[arrest['PERP_RACE']=='WHITE'])
B=(arrest[arrest['PERP_RACE']=='BLACK'])
H=(arrest[arrest['PERP_RACE']=='WHITE HISPANIC'])
A=(arrest[arrest['PERP_RACE']=='ASIAN / PACIFIC ISLANDER'])

# %%
plt.figure(figsize=(10,8))
plt.scatter(x=w['Longitude'],y=w['Latitude'],alpha=.5,s=.05,c='r')
plt.scatter(x=B['Longitude'],y=B['Latitude'],alpha=.5,s=.05,c='b')

# %% [markdown]
# ### graph of white and black crime commited in NYC
# ### It more likely that these crimes are committed where most people of those races live, you can see with this graph is heavyily around manhatten and bronx

# %%
(arrest.groupby(['ARREST_BORO','AGE_GROUP'])
.agg({'ARREST_KEY':'count'})).sort_values(by= 'ARREST_KEY',ascending = False).head()
# Out:
#                        ARREST_KEY
# ARREST_BORO AGE_GROUP
# K           25-44           24357
# M           25-44           22040
# B           25-44           20529
# Q           25-44           18680
# K           18-24            9689

# %% [markdown]
# #### Greatest number of arrest by Borough
# Broklyn is at the top of arrests by borough

# %%
plt.figure(figsize=(10,8))
plt.scatter(x=H['Longitude'],y=H['Latitude'],alpha=.5,s=.05,c='r')
plt.scatter(x=A['Longitude'],y=A['Latitude'],alpha=.5,s=.05,c='g')

# %% [markdown]
# ###  Graphs of Hispanics and Asians crimes are commited throughout NYC
# ### while with this map you see more hispanics in queens and long Island

# %%
(arrest.groupby(['PERP_SEX'])
.agg({'ARREST_KEY':'count'}).sort_values(by= 'ARREST_KEY',ascending=False))
# Out:
#           ARREST_KEY
# PERP_SEX
# M             137135
# F              30830

# %%
female_group = (arrest[arrest['PERP_SEX'] == 'F'])
male_group = (arrest[arrest['PERP_SEX'] == 'M'])

# %%
plt.figure(figsize=(10,8))
plt.scatter(x=female_group['Longitude'],y=female_group['Latitude'],alpha=.5,s=.05,c='b')
#plt.scatter(x=male_group['Longitude'],y=male_group['Latitude'],alpha=.5,s=.05,c='r')

# %% [markdown]
# ### This a graph of where most female and male crimes are commited throughout NYC

# %%
(arrest.groupby(['PERP_SEX'])
.agg({'ARREST_KEY':'count'}).sort_values(by= 'ARREST_KEY',ascending=False))
# Out:
#           ARREST_KEY
# PERP_SEX
# M             137135
# F              30830

# %% [markdown]
# ##### The number of male perpetrators quadruples the number of female perpetrators

# %%
uppermost_male = arrest[arrest['PERP_SEX']=='M']

# %%
(uppermost_male.groupby(['PERP_SEX','OFNS_DESC'])
.agg({'OFNS_DESC':lambda x:x.value_counts(),
      'ARREST_KEY':'count'})).sort_values(by= 'ARREST_KEY',ascending=False).head()
# Out:
#                                        OFNS_DESC  ARREST_KEY
# PERP_SEX OFNS_DESC
# M        ASSAULT 3 & RELATED OFFENSES      18130       18130
#          DANGEROUS DRUGS                   14576       14576
#          PETIT LARCENY                     12039       12039
#          VEHICLE AND TRAFFIC LAWS          10405       10405
#          FELONY ASSAULT                     8403        8403

# %%
TEST=(old.groupby(['ARREST_BORO','PERP_RACE'])
.agg({'OFNS_DESC':lambda x:x.value_counts(),
      'ARREST_KEY':'count'})).sort_values(by= 'ARREST_KEY',ascending=False)

# %%
TEST.plot.bar()
plt.ylim([0,350])
plt.xlim([0,20])

# %%
b= arrest[arrest['ARREST_BORO']=='B'].sort_index()

# %%
b.groupby('PERP_RACE').agg({'ARREST_KEY':'count'}).sort_values(by= 'ARREST_KEY',ascending=False).plot.bar()

# %%
plt.scatter(x=b['Longitude'],y=b['Latitude'],alpha=.5,s=.5,c='b')

# %% [markdown]
# ### the top races that crimes in that bronx

# %%
k = arrest[arrest['ARREST_BORO']=='K'].sort_index()

# %%
k.groupby('PERP_RACE').agg({'ARREST_KEY':'count'}).sort_values(by= 'ARREST_KEY',ascending=False).plot.bar()

# %% [markdown]
# ### the top races that commit crime in brooklyn

# %%
plt.scatter(x=k['Longitude'],y=k['Latitude'],alpha=.5,s=.5,c='b')

# %%
q = arrest[arrest['ARREST_BORO']=='Q'].sort_index()
q.groupby('PERP_RACE').agg({'ARREST_KEY':'count'}).sort_values(by= 'ARREST_KEY',ascending=False).plot.bar()

# %%
plt.scatter(x=q['Longitude'],y=q['Latitude'],alpha=.5,s=.5,c='b')

# %% [markdown]
# ### Crimes in queens

# %%
m = arrest[arrest['ARREST_BORO']=='M'].sort_index()
m.groupby('PERP_RACE').agg({'ARREST_KEY':'count'}).sort_values(by= 'ARREST_KEY',ascending=False).plot.bar()

# %%
plt.scatter(x=m['Longitude'],y=m['Latitude'],alpha=.5,s=.5,c='b')

# %% [markdown]
# ### crimes in Manhatten

# %%
test_group = (arrest[arrest['AGE_GROUP'] == '65+'])

# %%
old=arrest[arrest['AGE_GROUP']=='65+']
old.groupby('OFNS_DESC').size()
# Out:
# OFNS_DESC
# ADMINISTRATIVE CODE                      13
# AGRICULTURE & MRKTS LAW-UNCLASSIFIED      4
# ALCOHOLIC BEVERAGE CONTROL LAW            6
# ARSON                                     2
# ASSAULT 3 & RELATED OFFENSES            385
# BURGLAR'S TOOLS                          10
# BURGLARY                                 26
# CRIMINAL MISCHIEF & RELATED OF           66
# CRIMINAL TRESPASS                        40
# DANGEROUS DRUGS                         203
# DANGEROUS WEAPONS                        77
# DISORDERLY CONDUCT                       75
# ENDAN WELFARE INCOMP                      2
# FELONY ASSAULT                          184
# FOR OTHER AUTHORITIES                    16
# FORGERY                                  27
# FRAUDS                                    5
# FRAUDULENT ACCOSTING                      3
# GAMBLING                                 16
# GRAND LARCENY                            84
# GRAND LARCENY OF MOTOR VEHICLE            1
# ...

# %%
old.head()
# Out:
#      ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 80    203068790  2019-09-30  109.0        ASSAULT 2,1,UNCLASSIFIED  106.0
# 265   203061153  2019-09-30  782.0        WEAPONS, POSSESSION, ETC  236.0
# 323   203072425  2019-09-30  109.0        ASSAULT 2,1,UNCLASSIFIED  106.0
# 339   203061193  2019-09-30  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 361   203061089  2019-09-30  568.0  MARIJUANA, POSSESSION 1, 2 & 3  117.0
#
#              OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 80      FELONY ASSAULT  PL 1200501          F           Q              101
# 265  DANGEROUS WEAPONS  PL 2650101          M           M               24
# 323     FELONY ASSAULT  PL 1200502          F           Q              105
# 339      PETIT LARCENY  PL 1552500          M           Q              107
# 361    DANGEROUS DRUGS  PL 2212500          F           B               47
#
# ...

# %% [markdown]
# ### now we looking at data that people wouldnt normally look at
# ### people 65+ who commit crimes

# %%
TEST=(old.groupby(['PERP_SEX','OFNS_DESC'])
.agg({'OFNS_DESC':lambda x:x.value_counts(),
      'ARREST_KEY':'count'})).sort_values(by= 'ARREST_KEY',ascending=False)

# %%
TEST.plot.barh()
plt.ylim([0,20])
plt.xlim([0,350])
# Out:
# (0, 350)

# %%
plt.figure(figsize=(10,8))
plt.scatter(x=test_group['Longitude'],y=test_group['Latitude'],alpha=1,s=1,c='b')

# %%
males25 = (male_group[male_group['AGE_GROUP'] == '25-44'])

# %%
(males25.groupby(['ARREST_BORO','OFNS_DESC'])
.agg({'OFNS_DESC':lambda x:x.value_counts(),
      'ARREST_KEY':'count'})).sort_values(by= 'ARREST_KEY',ascending=False).head()
# Out:
#                                           OFNS_DESC  ARREST_KEY
# ARREST_BORO OFNS_DESC
# B           ASSAULT 3 & RELATED OFFENSES       2933        2933
# K           ASSAULT 3 & RELATED OFFENSES       2624        2624
# M           PETIT LARCENY                      2562        2562
# B           DANGEROUS DRUGS                    2314        2314
# Q           ASSAULT 3 & RELATED OFFENSES       2282        2282

# %%
complaint = pd.read_csv("NYPD_Complaint_Data_Current__Year_To_Date_.csv")
# Out:
# /Users/erickmolina/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
complaint
# Out:
#         CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0        660160752          103     QUEENS      9/30/19     14:00:00
# 1        219394661           40      BRONX      9/30/19     13:00:00
# 2        184671534           18  MANHATTAN      9/30/19     11:40:00
# 3        825219244           48      BRONX      9/30/19      2:00:00
# 4        457673231           32  MANHATTAN      9/29/19     20:30:00
# ...            ...          ...        ...          ...          ...
# 347069   599258223           67   BROOKLYN       1/1/19     12:00:00
# 347070   882145430           48      BRONX     12/31/18     15:00:00
# 347071   432296946           79   BROOKLYN       1/1/19     15:50:00
# 347072   609610620          102     QUEENS     11/28/18     16:54:00
# 347073   957637573           70   BROOKLYN     12/26/18     15:51:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# ...

# %%
complaint.columns
# Out:
# Index(['CMPLNT_NUM', 'ADDR_PCT_CD', 'BORO_NM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM',
#        'CMPLNT_TO_DT', 'CMPLNT_TO_TM', 'CRM_ATPT_CPTD_CD', 'HADEVELOPT',
#        'HOUSING_PSA', 'JURISDICTION_CODE', 'JURIS_DESC', 'KY_CD', 'LAW_CAT_CD',
#        'LOC_OF_OCCUR_DESC', 'OFNS_DESC', 'PARKS_NM', 'PATROL_BORO', 'PD_CD',
#        'PD_DESC', 'PREM_TYP_DESC', 'RPT_DT', 'STATION_NAME', 'SUSP_AGE_GROUP',
#        'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT', 'VIC_AGE_GROUP',
#        'VIC_RACE', 'VIC_SEX', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude',
#        'Longitude', 'Lat_Lon'],
#       dtype='object')

# %%
arrest.columns
# Out:
# Index(['ARREST_KEY', 'ARREST_DATE', 'PD_CD', 'PD_DESC', 'KY_CD', 'OFNS_DESC',
#        'LAW_CODE', 'LAW_CAT_CD', 'ARREST_BORO', 'ARREST_PRECINCT',
#        'JURISDICTION_CODE', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'X_COORD_CD',
#        'Y_COORD_CD', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
pd.concat([arrest.head(),complaint.head()],axis=1)
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0   203078287  2019-09-30  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 1   203072424  2019-09-30  268.0              CRIMINAL MIS 2 & 3  121.0
# 2   203061215  2019-09-30  905.0     INTOXICATED DRIVING,ALCOHOL  347.0
# 3   203061218  2019-09-30  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 4   203063729  2019-09-30  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
#
#                         OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                         ROBBERY  PL 1600500          F           M
# 1  CRIMINAL MISCHIEF & RELATED OF  PL 1450502          F           Q
# 2  INTOXICATED & IMPAIRED DRIVING  VTL11920U3          M           S
# 3                         ROBBERY  PL 1601502          F           S
# 4                         ROBBERY  PL 1601001          F           Q
#
#    ARREST_PRECINCT  ...  SUSP_SEX TRANSIT_DISTRICT VIC_AGE_GROUP VIC_RACE  \
# ...

# %%
(complaint.groupby(['BORO_NM','OFNS_DESC'])
.agg({'CMPLNT_NUM':'count'})).sort_values(by= 'CMPLNT_NUM',ascending = False).head()
# Out:
#                          CMPLNT_NUM
# BORO_NM   OFNS_DESC
# MANHATTAN PETIT LARCENY       21927
# BROOKLYN  PETIT LARCENY       18099
#           HARRASSMENT 2       15445
# BRONX     HARRASSMENT 2       12614
# QUEENS    PETIT LARCENY       12314

# %% [markdown]
# ### Top complaints for each borough 2019

# %%
(arrest.groupby(['ARREST_BORO'])
.agg({'ARREST_KEY':'count'})).sort_values(by= 'ARREST_KEY',ascending = False)
# Out:
#              ARREST_KEY
# ARREST_BORO
# K                 45842
# M                 41793
# B                 38309
# Q                 34864
# S                  7157

# %% [markdown]
# ### total arrest per borough

# %%
(complaint.groupby(['BORO_NM'])
.agg({'CMPLNT_NUM':'count'})).sort_values(by= 'CMPLNT_NUM',ascending = False)
# Out:
#                CMPLNT_NUM
# BORO_NM
# BROOKLYN            99976
# MANHATTAN           87095
# BRONX               76012
# QUEENS              69343
# STATEN ISLAND       14408

# %%
Nyc_pop = 8500000
Nyc_comp = 346834
rateNyc  = (Nyc_comp/Nyc_pop)* 100000
rateNyc
# Out:
# 4080.4

# %% [markdown]
# ### NYC complaint rate per 100,000 inhabitants¶
# In 2019 there were 346,834 complaints to the NYPD in New York City and the population is 8.5 million. This equals a complaint rate of 4,080 per 100,000.

# %%
Nyc_pop = 8500000
Nyc_arrest = 167965
arrestRateNyc  = (Nyc_arrest/Nyc_pop)* 100000
arrestRateNyc
# Out:
# 1976.0588235294117

# %% [markdown]
# ### Brooklyn complaint rate per 100,000 inhabitants
# In 2019 there were 99,976 complaints to the NYPD in Brooklyn and the population is 2,533,000. This equals a complaint rate of 3,947 per 100,000.

# %%
B_pop = 2533000
B_arrest = 45842
arrestRate  = (B_arrest/B_pop)* 100000
arrestRate
# Out:
# 1809.7907619423609

# %% [markdown]
# ### brooklyn arrest rate per 100,000 inhabitants¶
# In 2019 there were 45,842 arrest by the NYPD in Brooklyn. The population is 2,533,000. This equals an arrest rate of 1,810 per 100,000.

# %%
(complaint.groupby(['BORO_NM'])
.agg({'OFNS_DESC':lambda x:x.value_counts().index[0],
      'CMPLNT_NUM':'count'})).plot()

# %%
(complaint.groupby(['OFNS_DESC'])
.agg({'CMPLNT_NUM':'count'})).sort_values(by= 'CMPLNT_NUM',ascending = False).head().plot.barh()

# %%
(complaint.groupby(['SUSP_RACE'])
.agg({'BORO_NM':'count'}).sort_values(by= 'BORO_NM',ascending=False))
# Out:
#                                 BORO_NM
# SUSP_RACE
# BLACK                            100194
# UNKNOWN                           65750
# WHITE HISPANIC                    46363
# WHITE                             26556
# BLACK HISPANIC                    14866
# ASIAN / PACIFIC ISLANDER          10231
# AMERICAN INDIAN/ALASKAN NATIVE      827

# %% [markdown]
# tania&jorge

# %% [markdown]
# Conclusion:
# After analyzing the dataset “ NYPD Arrest Data Analysis” with the help of pandas, we came up with some interesting information. Each row in the data set represents an arrest episode in one of the five boroughs in NYC during the current year. People in the 25-44 age group tend to get arrested more often, while  the 65+ age group has the least amount of arrests. According to the data, males get arrested  at 4 times the rate of females. Also, where men age from 45-64 has a arrest report but women between that age do not have a history to get arrested. Surprisingly , according to the data ,  the borough of Brooklyn has the most arrest reports. Manhattan, Brooklyn and Queens all have a similar number of arrest reports. Staten Island came in last with the fewest number of arrests . We did some analyze on the age of 65+. They get arrested mostly for ASSAULT 3 AND RELATED OFFENSES , PETIT LARCENY  and for DISORDERLY CONDUCT. Also , the graphs show black men has the most arrest records than any other race.
